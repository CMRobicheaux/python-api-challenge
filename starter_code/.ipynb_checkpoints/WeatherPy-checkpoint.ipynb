# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url='http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key + "&q="
print("Beginning Data Retriveval")
print("---------------------------")
record_count=1
set_count=1
city_data=[]
for i,city in enumerate(cities):
    if(i%500==0 and i>=500):
        record_count=0
        set_count+=1
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count+=1
    city_url=url+city
    try:
        city_weather=requests.get(city_url).json()
        city_data.append({
             "City": city,
             "Lat": city_weather["coord"]["lat"],
             "Lon": city_weather["coord"]["lon"],
             "Max Temp": city_weather["main"]["temp_max"],
             "Humidity": city_weather["main"]["humidity"],
             "Wind Speed": city_weather["wind"]["speed"],
             "Country": city_weather["sys"]["country"],
             "Date": city_weather["dt"],
             "Clouds": city_weather["clouds"]["all"]
         })
    except:
        print("City not found. Skipping..")
        pass
print("-----------------------")
print("Data Retrieval Complete")
print("-----------------------")
# Out:
# Beginning Data Retriveval
# ---------------------------
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | mutsamudu
# City not found. Skipping..
# Processing Record 6 of Set 1 | ilulissat
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | samarai
# Processing Record 12 of Set 1 | jabiru
# City not found. Skipping..
# Processing Record 13 of Set 1 | olavarria
# Processing Record 14 of Set 1 | teya
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | cabo san lucas
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | tiksi
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | lebu
# Processing Record 23 of Set 1 | danville
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | pacific grove
# Processing Record 26 of Set 1 | port blair
# Processing Record 27 of Set 1 | korla
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | goderich
# Processing Record 30 of Set 1 | zhigansk
# Processing Record 31 of Set 1 | saint anthony
# Processing Record 32 of Set 1 | east london
# Processing Record 33 of Set 1 | saint george
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | idlib
# Processing Record 36 of Set 1 | castro
# Processing Record 37 of Set 1 | surt
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | chuy
# Processing Record 40 of Set 1 | upernavik
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | phan thiet
# Processing Record 43 of Set 1 | muyezerskiy
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | katangli
# Processing Record 47 of Set 1 | georgetown
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | hovd
# Processing Record 50 of Set 1 | mudon
# Processing Record 51 of Set 1 | hervey bay
# Processing Record 52 of Set 1 | topolobampo
# Processing Record 53 of Set 1 | vardo
# Processing Record 54 of Set 1 | kaufbeuren
# Processing Record 55 of Set 1 | hermanus
# Processing Record 56 of Set 1 | mataura
# Processing Record 57 of Set 1 | mar del plata
# Processing Record 58 of Set 1 | taolanaro
# City not found. Skipping..
# Processing Record 59 of Set 1 | tuktoyaktuk
# Processing Record 60 of Set 1 | victoria
# Processing Record 61 of Set 1 | san cristobal
# Processing Record 62 of Set 1 | rakai
# Processing Record 63 of Set 1 | cheuskiny
# City not found. Skipping..
# Processing Record 64 of Set 1 | abiy adi
# City not found. Skipping..
# Processing Record 65 of Set 1 | vaini
# Processing Record 66 of Set 1 | cape town
# Processing Record 67 of Set 1 | sawakin
# Processing Record 68 of Set 1 | belaya kholunitsa
# Processing Record 69 of Set 1 | bengkulu
# Processing Record 70 of Set 1 | kadoshkino
# Processing Record 71 of Set 1 | manicore
# Processing Record 72 of Set 1 | sorland
# Processing Record 73 of Set 1 | port said
# Processing Record 74 of Set 1 | nanortalik
# Processing Record 75 of Set 1 | carnarvon
# Processing Record 76 of Set 1 | bluff
# Processing Record 77 of Set 1 | arraial do cabo
# Processing Record 78 of Set 1 | omsukchan
# Processing Record 79 of Set 1 | warqla
# City not found. Skipping..
# Processing Record 80 of Set 1 | saint-augustin
# Processing Record 81 of Set 1 | ouadda
# Processing Record 82 of Set 1 | christchurch
# Processing Record 83 of Set 1 | rio gallegos
# Processing Record 84 of Set 1 | henties bay
# Processing Record 85 of Set 1 | klaksvik
# Processing Record 86 of Set 1 | butaritari
# Processing Record 87 of Set 1 | pouebo
# Processing Record 88 of Set 1 | ust-shonosha
# Processing Record 89 of Set 1 | illoqqortoormiut
# City not found. Skipping..
# Processing Record 90 of Set 1 | santa fe do sul
# Processing Record 91 of Set 1 | galiwinku
# City not found. Skipping..
# Processing Record 92 of Set 1 | batagay-alyta
# Processing Record 93 of Set 1 | ozernovskiy
# Processing Record 94 of Set 1 | poum
# Processing Record 95 of Set 1 | guerrero negro
# Processing Record 96 of Set 1 | saskylakh
# Processing Record 97 of Set 1 | husavik
# Processing Record 98 of Set 1 | nouakchott
# Processing Record 99 of Set 1 | avarua
# Processing Record 100 of Set 1 | valparaiso
# Processing Record 101 of Set 1 | cidreira
# Processing Record 102 of Set 1 | isangel
# Processing Record 103 of Set 1 | severo-kurilsk
# Processing Record 104 of Set 1 | provideniya
# Processing Record 105 of Set 1 | flinders
# Processing Record 106 of Set 1 | marcona
# City not found. Skipping..
# Processing Record 107 of Set 1 | jamestown
# Processing Record 108 of Set 1 | raga
# Processing Record 109 of Set 1 | hofn
# Processing Record 110 of Set 1 | baie-comeau
# Processing Record 111 of Set 1 | constitucion
# Processing Record 112 of Set 1 | halifax
# Processing Record 113 of Set 1 | caravelas
# Processing Record 114 of Set 1 | invermere
# Processing Record 115 of Set 1 | vaitupu
# City not found. Skipping..
# Processing Record 116 of Set 1 | la ronge
# Processing Record 117 of Set 1 | porto calvo
# Processing Record 118 of Set 1 | saint-philippe
# Processing Record 119 of Set 1 | ostrovnoy
# Processing Record 120 of Set 1 | ponte san nicolo
# Processing Record 121 of Set 1 | marawi
# Processing Record 122 of Set 1 | cayenne
# Processing Record 123 of Set 1 | lima
# Processing Record 124 of Set 1 | trairi
# Processing Record 125 of Set 1 | heidenau
# Processing Record 126 of Set 1 | shuyskoye
# Processing Record 127 of Set 1 | dolbeau
# City not found. Skipping..
# Processing Record 128 of Set 1 | sisimiut
# Processing Record 129 of Set 1 | roebourne
# Processing Record 130 of Set 1 | kedrovyy
# Processing Record 131 of Set 1 | belushya guba
# City not found. Skipping..
# Processing Record 132 of Set 1 | solovetskiy
# City not found. Skipping..
# Processing Record 133 of Set 1 | camacha
# Processing Record 134 of Set 1 | tutoia
# Processing Record 135 of Set 1 | ruatoria
# City not found. Skipping..
# Processing Record 136 of Set 1 | thomaston
# Processing Record 137 of Set 1 | lompoc
# Processing Record 138 of Set 1 | barentsburg
# City not found. Skipping..
# Processing Record 139 of Set 1 | carutapera
# Processing Record 140 of Set 1 | qandala
# Processing Record 141 of Set 1 | new norfolk
# Processing Record 142 of Set 1 | kaeo
# Processing Record 143 of Set 1 | dingle
# Processing Record 144 of Set 1 | belyy yar
# Processing Record 145 of Set 1 | bur gabo
# City not found. Skipping..
# Processing Record 146 of Set 1 | yellowknife
# Processing Record 147 of Set 1 | tilichiki
# Processing Record 148 of Set 1 | cherskiy
# Processing Record 149 of Set 1 | amderma
# City not found. Skipping..
# Processing Record 150 of Set 1 | coahuayana
# Processing Record 151 of Set 1 | peniche
# Processing Record 152 of Set 1 | sentyabrskiy
# City not found. Skipping..
# Processing Record 153 of Set 1 | nikolskoye
# Processing Record 154 of Set 1 | buariki
# City not found. Skipping..
# Processing Record 155 of Set 1 | tabiauea
# City not found. Skipping..
# Processing Record 156 of Set 1 | innisfail
# Processing Record 157 of Set 1 | lavrentiya
# Processing Record 158 of Set 1 | lebowakgomo
# Processing Record 159 of Set 1 | kieta
# Processing Record 160 of Set 1 | waingapu
# Processing Record 161 of Set 1 | sumenep
# Processing Record 162 of Set 1 | vao
# Processing Record 163 of Set 1 | troitsko-pechorsk
# Processing Record 164 of Set 1 | ponta delgada
# Processing Record 165 of Set 1 | loikaw
# Processing Record 166 of Set 1 | chokurdakh
# Processing Record 167 of Set 1 | ponta do sol
# Processing Record 168 of Set 1 | tsihombe
# City not found. Skipping..
# Processing Record 169 of Set 1 | anloga
# Processing Record 170 of Set 1 | longyearbyen
# Processing Record 171 of Set 1 | pangnirtung
# Processing Record 172 of Set 1 | sakakah
# Processing Record 173 of Set 1 | palanpur
# Processing Record 174 of Set 1 | ozark
# Processing Record 175 of Set 1 | ambodifototra
# City not found. Skipping..
# Processing Record 176 of Set 1 | airai
# Processing Record 177 of Set 1 | kassala
# Processing Record 178 of Set 1 | katsuura
# Processing Record 179 of Set 1 | souillac
# Processing Record 180 of Set 1 | tasiilaq
# Processing Record 181 of Set 1 | paamiut
# Processing Record 182 of Set 1 | tabou
# Processing Record 183 of Set 1 | calatayud
# Processing Record 184 of Set 1 | brae
# Processing Record 185 of Set 1 | swellendam
# Processing Record 186 of Set 1 | bowen
# Processing Record 187 of Set 1 | coalcoman
# City not found. Skipping..
# Processing Record 188 of Set 1 | kruisfontein
# Processing Record 189 of Set 1 | salalah
# Processing Record 190 of Set 1 | kaitangata
# Processing Record 191 of Set 1 | port macquarie
# Processing Record 192 of Set 1 | vinh
# Processing Record 193 of Set 1 | hobart
# Processing Record 194 of Set 1 | port keats
# Processing Record 195 of Set 1 | port elizabeth
# Processing Record 196 of Set 1 | accra
# Processing Record 197 of Set 1 | volsk
# Processing Record 198 of Set 1 | bilibino
# Processing Record 199 of Set 1 | yulara
# Processing Record 200 of Set 1 | bereznehuvate
# Processing Record 201 of Set 1 | sitka
# Processing Record 202 of Set 1 | maceio
# Processing Record 203 of Set 1 | esmeraldas
# Processing Record 204 of Set 1 | mys shmidta
# City not found. Skipping..
# Processing Record 205 of Set 1 | thompson
# Processing Record 206 of Set 1 | torbay
# Processing Record 207 of Set 1 | byron bay
# Processing Record 208 of Set 1 | quang ngai
# Processing Record 209 of Set 1 | kavaratti
# Processing Record 210 of Set 1 | labrea
# Processing Record 211 of Set 1 | faanui
# Processing Record 212 of Set 1 | phalodi
# Processing Record 213 of Set 1 | sovetskiy
# Processing Record 214 of Set 1 | vestmannaeyjar
# Processing Record 215 of Set 1 | hithadhoo
# Processing Record 216 of Set 1 | port augusta
# Processing Record 217 of Set 1 | taungdwingyi
# Processing Record 218 of Set 1 | nicoya
# Processing Record 219 of Set 1 | puerto del rosario
# Processing Record 220 of Set 1 | ambanja
# Processing Record 221 of Set 1 | nhulunbuy
# Processing Record 222 of Set 1 | murud
# Processing Record 223 of Set 1 | iralaya
# Processing Record 224 of Set 1 | kopervik
# Processing Record 225 of Set 1 | samusu
# City not found. Skipping..
# Processing Record 226 of Set 1 | clyde river
# Processing Record 227 of Set 1 | khasan
# Processing Record 228 of Set 1 | selenginsk
# Processing Record 229 of Set 1 | aykhal
# Processing Record 230 of Set 1 | rocha
# Processing Record 231 of Set 1 | yabrud
# Processing Record 232 of Set 1 | coquimbo
# Processing Record 233 of Set 1 | berlevag
# Processing Record 234 of Set 1 | kahului
# Processing Record 235 of Set 1 | beringovskiy
# Processing Record 236 of Set 1 | grand river south east
# City not found. Skipping..
# Processing Record 237 of Set 1 | emerald
# Processing Record 238 of Set 1 | pak phanang
# Processing Record 239 of Set 1 | adrar
# Processing Record 240 of Set 1 | rudnogorsk
# Processing Record 241 of Set 1 | mehamn
# Processing Record 242 of Set 1 | wadi maliz
# Processing Record 243 of Set 1 | zachagansk
# City not found. Skipping..
# Processing Record 244 of Set 1 | takanabe
# Processing Record 245 of Set 1 | gizo
# Processing Record 246 of Set 1 | powell river
# Processing Record 247 of Set 1 | shaoyang
# Processing Record 248 of Set 1 | thinadhoo
# Processing Record 249 of Set 1 | hualmay
# Processing Record 250 of Set 1 | kamenskoye
# City not found. Skipping..
# Processing Record 251 of Set 1 | juba
# Processing Record 252 of Set 1 | attawapiskat
# City not found. Skipping..
# Processing Record 253 of Set 1 | villazon
# Processing Record 254 of Set 1 | ambilobe
# Processing Record 255 of Set 1 | grand gaube
# Processing Record 256 of Set 1 | tuatapere
# Processing Record 257 of Set 1 | oranjestad
# Processing Record 258 of Set 1 | mount isa
# Processing Record 259 of Set 1 | san patricio
# Processing Record 260 of Set 1 | denpasar
# Processing Record 261 of Set 1 | quatre cocos
# Processing Record 262 of Set 1 | bondo
# Processing Record 263 of Set 1 | tevaitoa
# Processing Record 264 of Set 1 | male
# Processing Record 265 of Set 1 | eucaliptus
# Processing Record 266 of Set 1 | mahibadhoo
# Processing Record 267 of Set 1 | portland
# Processing Record 268 of Set 1 | olafsvik
# Processing Record 269 of Set 1 | zabol
# Processing Record 270 of Set 1 | havelock
# Processing Record 271 of Set 1 | onega
# Processing Record 272 of Set 1 | north platte
# Processing Record 273 of Set 1 | palana
# Processing Record 274 of Set 1 | borogontsy
# Processing Record 275 of Set 1 | marquette
# Processing Record 276 of Set 1 | bargal
# City not found. Skipping..
# Processing Record 277 of Set 1 | andenes
# Processing Record 278 of Set 1 | santa cruz
# Processing Record 279 of Set 1 | kalmunai
# Processing Record 280 of Set 1 | storforshei
# Processing Record 281 of Set 1 | hwange
# Processing Record 282 of Set 1 | launceston
# Processing Record 283 of Set 1 | duminichi
# Processing Record 284 of Set 1 | bodden town
# Processing Record 285 of Set 1 | sao gabriel da cachoeira
# Processing Record 286 of Set 1 | vitanesti
# Processing Record 287 of Set 1 | saint marys
# Processing Record 288 of Set 1 | talawdi
# City not found. Skipping..
# Processing Record 289 of Set 1 | lakes entrance
# Processing Record 290 of Set 1 | daru
# Processing Record 291 of Set 1 | ribeira grande
# Processing Record 292 of Set 1 | kommunisticheskiy
# Processing Record 293 of Set 1 | stykkisholmur
# Processing Record 294 of Set 1 | eirunepe
# Processing Record 295 of Set 1 | ketchikan
# Processing Record 296 of Set 1 | noumea
# Processing Record 297 of Set 1 | alihe
# Processing Record 298 of Set 1 | kayanga
# Processing Record 299 of Set 1 | acarau
# Processing Record 300 of Set 1 | leningradskiy
# Processing Record 301 of Set 1 | saldanha
# Processing Record 302 of Set 1 | kazachinskoye
# Processing Record 303 of Set 1 | naze
# Processing Record 304 of Set 1 | hue
# Processing Record 305 of Set 1 | barbar
# City not found. Skipping..
# Processing Record 306 of Set 1 | pisco
# Processing Record 307 of Set 1 | bilma
# Processing Record 308 of Set 1 | bethel
# Processing Record 309 of Set 1 | kurumkan
# Processing Record 310 of Set 1 | palabuhanratu
# City not found. Skipping..
# Processing Record 311 of Set 1 | impfondo
# Processing Record 312 of Set 1 | kisangani
# Processing Record 313 of Set 1 | ondjiva
# Processing Record 314 of Set 1 | mahebourg
# Processing Record 315 of Set 1 | pitharion
# Processing Record 316 of Set 1 | farsund
# Processing Record 317 of Set 1 | cieza
# Processing Record 318 of Set 1 | saint-vallier
# Processing Record 319 of Set 1 | ullapool
# Processing Record 320 of Set 1 | najran
# Processing Record 321 of Set 1 | acapulco
# Processing Record 322 of Set 1 | yefira
# City not found. Skipping..
# Processing Record 323 of Set 1 | fairbanks
# Processing Record 324 of Set 1 | fevralsk
# City not found. Skipping..
# Processing Record 325 of Set 1 | lata
# Processing Record 326 of Set 1 | ust-karsk
# Processing Record 327 of Set 1 | faya
# Processing Record 328 of Set 1 | vila
# Processing Record 329 of Set 1 | narsaq
# Processing Record 330 of Set 1 | dutlwe
# Processing Record 331 of Set 1 | petropavlovka
# Processing Record 332 of Set 1 | rawson
# Processing Record 333 of Set 1 | kamaishi
# Processing Record 334 of Set 1 | sept-iles
# Processing Record 335 of Set 1 | channel-port aux basques
# Processing Record 336 of Set 1 | bubaque
# Processing Record 337 of Set 1 | aklavik
# Processing Record 338 of Set 1 | san jose
# Processing Record 339 of Set 1 | padang
# Processing Record 340 of Set 1 | oeiras do para
# Processing Record 341 of Set 1 | bambous virieux
# Processing Record 342 of Set 1 | bonavista
# Processing Record 343 of Set 1 | vanderhoof
# Processing Record 344 of Set 1 | maunabo
# Processing Record 345 of Set 1 | cooma
# Processing Record 346 of Set 1 | kotido
# Processing Record 347 of Set 1 | beckley
# Processing Record 348 of Set 1 | rio branco
# Processing Record 349 of Set 1 | umzimvubu
# City not found. Skipping..
# Processing Record 350 of Set 1 | selikhino
# Processing Record 351 of Set 1 | boueni
# Processing Record 352 of Set 1 | edson
# Processing Record 353 of Set 1 | opuwo
# Processing Record 354 of Set 1 | jalu
# Processing Record 355 of Set 1 | ahipara
# Processing Record 356 of Set 1 | cortez
# Processing Record 357 of Set 1 | nome
# Processing Record 358 of Set 1 | mayumba
# Processing Record 359 of Set 1 | makakilo city
# Processing Record 360 of Set 1 | kibala
# Processing Record 361 of Set 1 | tezu
# Processing Record 362 of Set 1 | mergui
# City not found. Skipping..
# Processing Record 363 of Set 1 | maniitsoq
# Processing Record 364 of Set 1 | semikarakorsk
# Processing Record 365 of Set 1 | port lincoln
# Processing Record 366 of Set 1 | marystown
# Processing Record 367 of Set 1 | hamilton
# Processing Record 368 of Set 1 | namtsy
# Processing Record 369 of Set 1 | havoysund
# Processing Record 370 of Set 1 | alugan
# Processing Record 371 of Set 1 | sorong
# Processing Record 372 of Set 1 | kazalinsk
# City not found. Skipping..
# Processing Record 373 of Set 1 | boyolangu
# Processing Record 374 of Set 1 | mayo
# Processing Record 375 of Set 1 | trincomalee
# Processing Record 376 of Set 1 | coihaique
# Processing Record 377 of Set 1 | saleaula
# City not found. Skipping..
# Processing Record 378 of Set 1 | lashio
# Processing Record 379 of Set 1 | el alto
# Processing Record 380 of Set 1 | sur
# Processing Record 381 of Set 1 | san andres
# Processing Record 382 of Set 1 | ewa beach
# Processing Record 383 of Set 1 | lolua
# City not found. Skipping..
# Processing Record 384 of Set 1 | serenje
# Processing Record 385 of Set 1 | tazmalt
# Processing Record 386 of Set 1 | bandarban
# Processing Record 387 of Set 1 | nouadhibou
# Processing Record 388 of Set 1 | norman wells
# Processing Record 389 of Set 1 | sambava
# Processing Record 390 of Set 1 | sestri levante
# Processing Record 391 of Set 1 | ovar
# Processing Record 392 of Set 1 | bardiyah
# Processing Record 393 of Set 1 | cabedelo
# Processing Record 394 of Set 1 | saint-georges
# Processing Record 395 of Set 1 | biak
# Processing Record 396 of Set 1 | hami
# Processing Record 397 of Set 1 | villa nueva
# Processing Record 398 of Set 1 | necochea
# Processing Record 399 of Set 1 | mount gambier
# Processing Record 400 of Set 1 | lorengau
# Processing Record 401 of Set 1 | vallenar
# Processing Record 402 of Set 1 | da lat
# Processing Record 403 of Set 1 | alghero
# Processing Record 404 of Set 1 | rongcheng
# Processing Record 405 of Set 1 | urucara
# Processing Record 406 of Set 1 | bojnurd
# Processing Record 407 of Set 1 | talnakh
# Processing Record 408 of Set 1 | lagoa
# Processing Record 409 of Set 1 | broome
# Processing Record 410 of Set 1 | cairns
# Processing Record 411 of Set 1 | puri
# Processing Record 412 of Set 1 | kiama
# Processing Record 413 of Set 1 | lubliniec
# Processing Record 414 of Set 1 | mozhaysk
# Processing Record 415 of Set 1 | raufoss
# Processing Record 416 of Set 1 | marang
# Processing Record 417 of Set 1 | korem
# Processing Record 418 of Set 1 | luderitz
# Processing Record 419 of Set 1 | haibowan
# City not found. Skipping..
# Processing Record 420 of Set 1 | turukhansk
# Processing Record 421 of Set 1 | cangucu
# Processing Record 422 of Set 1 | nuuk
# Processing Record 423 of Set 1 | shujalpur
# Processing Record 424 of Set 1 | kulhudhuffushi
# Processing Record 425 of Set 1 | tias
# Processing Record 426 of Set 1 | caxito
# Processing Record 427 of Set 1 | rozhnyativ
# Processing Record 428 of Set 1 | matai
# Processing Record 429 of Set 1 | louisbourg
# City not found. Skipping..
# Processing Record 430 of Set 1 | yar-sale
# Processing Record 431 of Set 1 | warrington
# Processing Record 432 of Set 1 | dryden
# Processing Record 433 of Set 1 | shaunavon
# Processing Record 434 of Set 1 | ulaanbaatar
# Processing Record 435 of Set 1 | namatanai
# Processing Record 436 of Set 1 | bartica
# Processing Record 437 of Set 1 | port-cartier
# Processing Record 438 of Set 1 | alofi
# Processing Record 439 of Set 1 | belaya gora
# Processing Record 440 of Set 1 | eenhana
# Processing Record 441 of Set 1 | darhan
# Processing Record 442 of Set 1 | manta
# Processing Record 443 of Set 1 | dzhusaly
# City not found. Skipping..
# Processing Record 444 of Set 1 | westport
# Processing Record 445 of Set 1 | shawville
# Processing Record 446 of Set 1 | chicama
# Processing Record 447 of Set 1 | bolungarvik
# City not found. Skipping..
# Processing Record 448 of Set 1 | tananger
# Processing Record 449 of Set 1 | acajutla
# Processing Record 450 of Set 1 | praia
# Processing Record 451 of Set 1 | tura
# Processing Record 452 of Set 1 | bahia de caraquez
# Processing Record 453 of Set 1 | wajima
# Processing Record 454 of Set 1 | yacuiba
# Processing Record 455 of Set 1 | nioro
# Processing Record 456 of Set 1 | alta floresta
# Processing Record 457 of Set 1 | barra do garcas
# Processing Record 458 of Set 1 | rawannawi
# City not found. Skipping..
# Processing Record 459 of Set 1 | alotau
# City not found. Skipping..
# Processing Record 460 of Set 1 | kupang
# Processing Record 461 of Set 1 | muros
# Processing Record 462 of Set 1 | mitsamiouli
# Processing Record 463 of Set 1 | bengkalis
# City not found. Skipping..
# Processing Record 464 of Set 1 | watsa
# Processing Record 465 of Set 1 | qianan
# Processing Record 466 of Set 1 | serebryansk
# Processing Record 467 of Set 1 | phan rang
# City not found. Skipping..
# Processing Record 468 of Set 1 | kyzyl-mazhalyk
# Processing Record 469 of Set 1 | pokhara
# Processing Record 470 of Set 1 | inuvik
# Processing Record 471 of Set 1 | nieuw amsterdam
# Processing Record 472 of Set 1 | abu dhabi
# Processing Record 473 of Set 1 | nenjiang
# Processing Record 474 of Set 1 | kodiak
# Processing Record 475 of Set 1 | lasa
# Processing Record 476 of Set 1 | dongsheng
# Processing Record 477 of Set 1 | goure
# Processing Record 478 of Set 1 | cape canaveral
# Processing Record 479 of Set 1 | qidong
# Processing Record 480 of Set 1 | nishihara
# Processing Record 481 of Set 1 | vanimo
# Processing Record 482 of Set 1 | erdenet
# Processing Record 483 of Set 1 | entre rios
# Processing Record 484 of Set 1 | vila franca do campo
# Processing Record 485 of Set 1 | santa maria
# Processing Record 486 of Set 1 | ancud
# Processing Record 487 of Set 1 | namibe
# Processing Record 488 of Set 1 | chernyshevskiy
# Processing Record 489 of Set 1 | aswan
# Processing Record 490 of Set 1 | mango
# Processing Record 491 of Set 1 | nemuro
# Processing Record 492 of Set 1 | hun
# Processing Record 493 of Set 1 | saint-francois
# Processing Record 494 of Set 1 | tamiahua
# Processing Record 495 of Set 1 | sorvag
# City not found. Skipping..
# Processing Record 496 of Set 1 | seydi
# Processing Record 497 of Set 1 | the valley
# Processing Record 498 of Set 1 | vila velha
# Processing Record 499 of Set 1 | agirish
# Processing Record 500 of Set 1 | yumen
# Processing Record 0 of Set 2 | fortuna
# Processing Record 1 of Set 2 | kangaatsiaq
# Processing Record 2 of Set 2 | yeppoon
# Processing Record 3 of Set 2 | poitiers
# Processing Record 4 of Set 2 | fuerte olimpo
# Processing Record 5 of Set 2 | borovoy
# Processing Record 6 of Set 2 | taoudenni
# Processing Record 7 of Set 2 | bani
# Processing Record 8 of Set 2 | haines junction
# Processing Record 9 of Set 2 | bud
# Processing Record 10 of Set 2 | komsomolskiy
# Processing Record 11 of Set 2 | esperance
# Processing Record 12 of Set 2 | izhma
# Processing Record 13 of Set 2 | galle
# Processing Record 14 of Set 2 | benguela
# Processing Record 15 of Set 2 | shimoda
# Processing Record 16 of Set 2 | araouane
# Processing Record 17 of Set 2 | chunskiy
# Processing Record 18 of Set 2 | svobodnyy
# Processing Record 19 of Set 2 | staryy nadym
# Processing Record 20 of Set 2 | kichera
# Processing Record 21 of Set 2 | iwanai
# Processing Record 22 of Set 2 | tumannyy
# City not found. Skipping..
# Processing Record 23 of Set 2 | helong
# Processing Record 24 of Set 2 | nigde
# Processing Record 25 of Set 2 | thanh hoa
# Processing Record 26 of Set 2 | saryshagan
# City not found. Skipping..
# Processing Record 27 of Set 2 | ucluelet
# Processing Record 28 of Set 2 | pocone
# Processing Record 29 of Set 2 | maromitsa
# Processing Record 30 of Set 2 | ugoofaaru
# Processing Record 31 of Set 2 | nampa
# Processing Record 32 of Set 2 | jardim
# Processing Record 33 of Set 2 | kapiri mposhi
# Processing Record 34 of Set 2 | kerteh
# City not found. Skipping..
# Processing Record 35 of Set 2 | sfantu gheorghe
# Processing Record 36 of Set 2 | santana do livramento
# Processing Record 37 of Set 2 | sabha
# Processing Record 38 of Set 2 | kidal
# Processing Record 39 of Set 2 | oswiecim
# Processing Record 40 of Set 2 | dicabisagan
# Processing Record 41 of Set 2 | play cu
# City not found. Skipping..
# Processing Record 42 of Set 2 | kaohsiung
# Processing Record 43 of Set 2 | eureka
# Processing Record 44 of Set 2 | gamba
# Processing Record 45 of Set 2 | whitianga
# Processing Record 46 of Set 2 | geraldton
# Processing Record 47 of Set 2 | tomatlan
# Processing Record 48 of Set 2 | iqaluit
# Processing Record 49 of Set 2 | manastirea
# Processing Record 50 of Set 2 | khilok
# Processing Record 51 of Set 2 | pangai
# Processing Record 52 of Set 2 | augusta
# Processing Record 53 of Set 2 | zanjan
# Processing Record 54 of Set 2 | troitskoye
# Processing Record 55 of Set 2 | saint quentin
# City not found. Skipping..
# Processing Record 56 of Set 2 | college
# Processing Record 57 of Set 2 | dianopolis
# City not found. Skipping..
# Processing Record 58 of Set 2 | matara
# Processing Record 59 of Set 2 | lukow
# Processing Record 60 of Set 2 | buala
# Processing Record 61 of Set 2 | vostok
# Processing Record 62 of Set 2 | salinopolis
# Processing Record 63 of Set 2 | kloulklubed
# Processing Record 64 of Set 2 | kapit
# Processing Record 65 of Set 2 | visnes
# Processing Record 66 of Set 2 | touros
# Processing Record 67 of Set 2 | viedma
# Processing Record 68 of Set 2 | malanje
# Processing Record 69 of Set 2 | trier
# Processing Record 70 of Set 2 | ballina
# Processing Record 71 of Set 2 | misratah
# Processing Record 72 of Set 2 | duluth
# Processing Record 73 of Set 2 | vilyuysk
# Processing Record 74 of Set 2 | boyuibe
# Processing Record 75 of Set 2 | labutta
# City not found. Skipping..
# Processing Record 76 of Set 2 | richards bay
# Processing Record 77 of Set 2 | pangody
# Processing Record 78 of Set 2 | hobyo
# Processing Record 79 of Set 2 | sarakhs
# Processing Record 80 of Set 2 | baruun-urt
# Processing Record 81 of Set 2 | ginir
# Processing Record 82 of Set 2 | pontal do parana
# Processing Record 83 of Set 2 | mogadishu
# Processing Record 84 of Set 2 | kropotkin
# Processing Record 85 of Set 2 | redlands
# Processing Record 86 of Set 2 | ribeira brava
# Processing Record 87 of Set 2 | sangar
# Processing Record 88 of Set 2 | trelew
# Processing Record 89 of Set 2 | north bend
# Processing Record 90 of Set 2 | nelson bay
# -----------------------
# Data Retrieval Complete
# -----------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data = pd.DataFrame(city_data)
weather_data.head()
# Out:
#                 City    Lat     Lon  Max Temp  Humidity  Wind Speed Country  \
# 0  sao joao da barra -21.64  -41.05     80.60        65        9.17      BR
# 1            kavieng  -2.57  150.80     83.16        74        5.46      PG
# 2            rikitea -23.12 -134.97     78.87        79       13.20      PF
# 3             hasaki  35.73  140.83     39.20        64       10.29      JP
# 4          ilulissat  69.22  -51.10      8.60        60        1.12      GL
#
#          Date  Clouds
# 0  1580076765      35
# 1  1580076765       0
# 2  1580076658       0
# 3  1580076766      75
# 4  1580076766      91

# %%
weather_data.to_csv("weather_data.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Max Temp"],edgecolors="purple",facecolors="pink")
plt.title("City Latitude vs. Max Temperature (05/28/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Humidity"],edgecolors="purple",facecolors="pink")
plt.title("City Latitude vs. Humidity (05/28/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(-10,310)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Clouds"],edgecolors="purple",facecolors="pink")
plt.title("City Latitude vs. Cloudiness (05/28/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-10,100)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"],weather_data["Wind Speed"],edgecolors="purple",facecolors="pink")
plt.title("City Latitude vs. Windspeed(mph) (05/28/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(0,40)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
north= weather_data[weather_data['Lat']>=0]
south= weather_data[weather_data['Lon']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(north["Lat"],north["Max Temp"],edgecolors="purple",facecolors="pink")
plt.title("Nothern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.ylim(-49,100)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north["Lat"], north["Max Temp"])
regress_values = north["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(north["Lat"],regress_values,"r-")
plt.annotate(line_eq,(0,1),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(south["Lat"],south["Max Temp"],edgecolors="purple",facecolors="pink")
plt.title("Southern Hemisphere - Max Temp vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.ylim(-49,200)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south["Lat"], south["Max Temp"])
regress_values = south["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(south["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-50,1),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(north["Lat"],north["Humidity"],edgecolors="purple",facecolors="pink")
plt.title("Nothern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(0,120)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north["Lat"], north["Humidity"])
regress_values = north["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(north["Lat"],regress_values,"r-")
plt.annotate(line_eq,(50,25),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(south["Lat"],south["Humidity"],edgecolors="purple",facecolors="pink")
plt.title("Southern Hemisphere - Humidity vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(-49,150)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south["Lat"], south["Humidity"])
regress_values = south["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(south["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-50,1),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(north["Lat"],north["Clouds"],edgecolors="purple",facecolors="pink")
plt.title("Nothern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-20,120)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north["Lat"], north["Clouds"])
regress_values = north["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(north["Lat"],regress_values,"r-")
plt.annotate(line_eq,(55,45),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(south["Lat"],south["Clouds"],edgecolors="purple",facecolors="pink")
plt.title("Southern Hemisphere - Cloudiness vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.ylim(-10,120)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south["Lat"], south["Clouds"])
regress_values = south["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(south["Lat"],regress_values,"r-")
plt.annotate(line_eq,(50,50),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(north["Lat"],north["Wind Speed"],edgecolors="purple",facecolors="pink")
plt.title("Nothern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-10,60)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(north["Lat"], north["Wind Speed"])
regress_values = north["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(north["Lat"],regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(south["Lat"],south["Wind Speed"],edgecolors="purple",facecolors="pink")
plt.title("Southern Hemisphere - Wind Speed vs. Latitude")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (Mph)")
plt.ylim(-10,40)
plt.grid (b=True, which="major", axis="both", linestyle="-",color="lightgrey")
(slope, intercept, rvalue, pvalue, stderr) = linregress(south["Lat"], south["Wind Speed"])
regress_values = south["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(south["Lat"],regress_values,"r-")
plt.annotate(line_eq,(0,30),fontsize=15,color="red")
plt.show()
